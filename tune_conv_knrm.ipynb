# %%
import subprocess
import shlex
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]=""

# %%
fn = "./examples/tweets/config/conv_knrm_tweet.config"
for i in range(10, 301, 10):
    f = open(fn)
    f2 = open(fn+"_tmp", "w")
    for l in f:
        if "test_weights_iters" in l:
            l = "\"test_weights_iters\": {}, ".format(i)
        f2.write(l)
    f2.close()
    pargs = shlex.split("python matchzoo/main.py --phase predict --model_file {}_tmp".format(fn))
    p = subprocess.Popen(pargs, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    pout, perr = p.communicate()
    pargs = shlex.split("./eval/trec_eval.9.0/trec_eval qrels.microblog2014.txt data/tweets/predict.test.conv_knrm_ranking.txt")
    p = subprocess.Popen(pargs, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    pout, perr = p.communicate()
    lines = pout.split(b'\n')
    if len(perr) > 0:
        print(perr)
    print(i)
    for l in lines:
        l = l.decode("utf8")
        for metric in ["map", "recip_rank", "P_30"]:
            if l.startswith(metric):
                print(l)
# Out:
# 10
# map                   	all	0.2866
# recip_rank            	all	0.5589
# P_30                  	all	0.4224
# 20
# map                   	all	0.2917
# recip_rank            	all	0.5796
# P_30                  	all	0.4115
# 30
# map                   	all	0.2796
# recip_rank            	all	0.6321
# P_30                  	all	0.4079
# 40
# map                   	all	0.2867
# recip_rank            	all	0.5873
# P_30                  	all	0.4145
# 50
# map                   	all	0.2680
# recip_rank            	all	0.5434
# P_30                  	all	0.3806
# 60
# map                   	all	0.2712
# recip_rank            	all	0.5632
# P_30                  	all	0.3879
# 70
# map                   	all	0.2712
# recip_rank            	all	0.5632
# P_30                  	all	0.3879
# 80
# map                   	all	0.2712
# recip_rank            	all	0.5632
# P_30                  	all	0.3879
# 90
# map                   	all	0.2712
# recip_rank            	all	0.5632
# ...

# %%
fn = "./examples/tweets/config/conv_knrm_tweet.config"
for i in range(10, 301, 10):
    f = open(fn)
    f2 = open(fn+"_tmp", "w")
    for l in f:
        if "test_weights_iters" in l:
            l = "\"test_weights_iters\": {}, ".format(i)
        f2.write(l)
    f2.close()
    pargs = shlex.split("python matchzoo/main.py --phase predict --model_file {}_tmp".format(fn))
    p = subprocess.Popen(pargs, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    pout, perr = p.communicate()
    pargs = shlex.split("./eval/trec_eval.9.0/trec_eval qrels.microblog2014.txt data/tweets/predict.test.conv_knrm_ranking.txt")
    p = subprocess.Popen(pargs, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    pout, perr = p.communicate()
    lines = pout.split(b'\n')
    if len(perr) > 0:
        print(perr)
    print(i)
    for l in lines:
        l = l.decode("utf8")
        for metric in ["map", "recip_rank", "P_30"]:
            if l.startswith(metric):
                print(l)
# Out:
# 70
# map                   	all	0.2611
# recip_rank            	all	0.5453
# P_30                  	all	0.3733
# 80
# map                   	all	0.2555
# recip_rank            	all	0.5202
# P_30                  	all	0.3685
# 90
# map                   	all	0.2620
# recip_rank            	all	0.5318
# P_30                  	all	0.3764
# 100
# map                   	all	0.2600
# recip_rank            	all	0.5493
# P_30                  	all	0.3667
# 110
# map                   	all	0.2544
# recip_rank            	all	0.5472
# P_30                  	all	0.3655
# 120
# map                   	all	0.2659
# recip_rank            	all	0.5075
# P_30                  	all	0.3915
# 130
# map                   	all	0.2512
# recip_rank            	all	0.5195
# P_30                  	all	0.3612
# 140
# map                   	all	0.2657
# recip_rank            	all	0.5530
# P_30                  	all	0.3830
# 150
# map                   	all	0.2642
# recip_rank            	all	0.5557
# ...
