# %%
import subprocess
import shlex
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]=""

# %%
fn = "./examples/tweets/config/knrm_tweet.config"
for i in range(10, 300, 10):
    f = open(fn)
    f2 = open(fn+"_tmp", "w")
    for l in f:
        if "test_weights_iters" in l:
            l = "\"test_weights_iters\": {}, ".format(i)
        f2.write(l)
    f2.close()
    pargs = shlex.split("python matchzoo/main.py --phase predict --model_file {}_tmp".format(fn))
    p = subprocess.Popen(pargs, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    pout, perr = p.communicate()
#     if len(perr) > 0:
#         print(perr)
    pargs = shlex.split("./eval/trec_eval.9.0/trec_eval qrels.microblog2014.txt data/tweets/predict.test.knrm.txt")
    p = subprocess.Popen(pargs, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    pout, perr = p.communicate()
    lines = pout.split(b'\n')
    if len(perr) > 0:
        print(perr)
    print(i)
    for l in lines:
        l = l.decode("utf8")
        for metric in ["map", "recip_rank", "P_30"]:
            if l.startswith(metric):
                print(l)
# Out:
# 10
# map                   	all	0.2328
# recip_rank            	all	0.5679
# P_30                  	all	0.4006
# 20
# map                   	all	0.2364
# recip_rank            	all	0.6592
# P_30                  	all	0.3964
# 30
# map                   	all	0.2213
# recip_rank            	all	0.5353
# P_30                  	all	0.3436
# 40
# map                   	all	0.2729
# recip_rank            	all	0.6540
# P_30                  	all	0.4267
# 50
# map                   	all	0.2263
# recip_rank            	all	0.5541
# P_30                  	all	0.3691
# 60
# map                   	all	0.2514
# recip_rank            	all	0.5966
# P_30                  	all	0.3824
# 70
# map                   	all	0.2810
# recip_rank            	all	0.6234
# P_30                  	all	0.4376
# 80
# map                   	all	0.2833
# recip_rank            	all	0.5969
# P_30                  	all	0.4479
# 90
# map                   	all	0.2512
# recip_rank            	all	0.5633
# P_30                  	all	0.4152
# 100
# map                   	all	0.2524
# recip_rank            	all	0.5876
# P_30                  	all	0.4224
# 110
# map                   	all	0.2661
# recip_rank            	all	0.5991
# P_30                  	all	0.4285
# 120
# map                   	all	0.2721
# recip_rank            	all	0.6241
# P_30                  	all	0.4333
# 130
# map                   	all	0.2565
# recip_rank            	all	0.6095
# P_30                  	all	0.4212
# 140
# map                   	all	0.2736
# recip_rank            	all	0.6008
# P_30                  	all	0.4273
# 150
# map                   	all	0.2841
# recip_rank            	all	0.5829
# P_30                  	all	0.4345
# 160
# map                   	all	0.2757
# recip_rank            	all	0.5818
# P_30                  	all	0.4158
# 170
# map                   	all	0.2644
# recip_rank            	all	0.5931
# P_30                  	all	0.4109
# 180
# map                   	all	0.2682
# recip_rank            	all	0.6109
# P_30                  	all	0.4200
# 190
# map                   	all	0.2166
# recip_rank            	all	0.4711
# P_30                  	all	0.3255
# 200
# map                   	all	0.2727
# recip_rank            	all	0.5776
# P_30                  	all	0.4133
# 210
# map                   	all	0.2619
# recip_rank            	all	0.5633
# P_30                  	all	0.4024
# 220
# map                   	all	0.2757
# recip_rank            	all	0.6179
# P_30                  	all	0.4170
# 230
# map                   	all	0.2436
# recip_rank            	all	0.5438
# P_30                  	all	0.3697
# 240
# map                   	all	0.2520
# recip_rank            	all	0.5910
# P_30                  	all	0.3770
# 250
# map                   	all	0.2528
# recip_rank            	all	0.5911
# P_30                  	all	0.3842
# 260
# map                   	all	0.2667
# recip_rank            	all	0.5942
# P_30                  	all	0.4139
# 270
# map                   	all	0.2634
# recip_rank            	all	0.5563
# P_30                  	all	0.3939
# 280
# map                   	all	0.2532
# recip_rank            	all	0.5311
# P_30                  	all	0.3691
# 290
# map                   	all	0.2682
# recip_rank            	all	0.6040
# P_30                  	all	0.3891
